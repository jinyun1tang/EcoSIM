# %%
#use:
#plot output for sample
#
import netCDF4 as nc
import numpy as np
import matplotlib.pyplot as plt
import VisualLib as VSLib

# %%
ncfile='../sample/sample.ecosim.h0.1800-01-01-00000.nc'

year0=VSLib.get_hist_yr(ncfile)
# Open the NetCDF file
nc_file = nc.Dataset(ncfile, 'r')
print('year0=%d'%year0)
print("\nVariables:")
for var_name in nc_file.variables:
    print(var_name)
# Out:
# year0=1800
#
# Variables:
# ACTV_LYR
# AIR_TEMP
# AMENDED_C
# AMENDED_N
# AMENDED_P
# ATM_CH4
# ATM_CO2
# AUTO_RESP
# BLYR_RSC_CO2
# BLYR_RSC_H2O
# BRANCH_NO
# CAN_CO2
# CAN_CO2_FLX
# CAN_G
# CAN_GPP
# CAN_H
# CAN_HT
# CAN_LE
# CAN_RA
# CAN_RN
# CAN_TEMPC
# CAN_TEMPK
# CH4_FLX
# CH4_vr
# CO2_FLX
# CO2_LITR
# CO2_vr
# C_PARTS_brch_01
# C_PARTS_brch_02
# C_PARTS_brch_03
# C_PARTS_brch_04
# C_PARTS_brch_05
# C_PARTS_brch_06
# C_PARTS_brch_07
# C_PARTS_brch_08
# C_PARTS_brch_09
# C_PARTS_brch_10
# Canopy_PAR
# DISCHG_FLX
# DNS_RT_vr
# ECND_vr
# ECO_G
# ECO_GPP
# ECO_H
# ECO_HVST_C
# ECO_HVST_N
# ECO_HVST_P
# ECO_LAI
# ECO_LE
# ECO_NEE_CO2
# ECO_NPP
# ECO_RA
# ECO_RH
# ECO_Radnet
# ET
# EVAPN
# EXUD_C_FLX
# EXUD_N_FLX
# EXUD_P_FLX
# FIREp_CH4_FLX
# FIREp_CO2_FLX
# FIREp_N_FLX
# FIREp_P_FLX
# GRAIN_C
# GRAIN_N
# GRAIN_NO
# GRAIN_P
# Growth_Stage
# HMAX_AIR
# HMIN_AIR
# HUM
# HUMUS_C
# HUMUS_N
# HUMUS_P
# HUSK_C
# HUSK_N
# HUSK_P
# HVST_C_FLX
# HVST_N_FLX
# HVST_P_FLX
# HeatFlx2G_col
# LAI_xstk
# LAIstk
# LEAF_C
# LEAF_N
# LEAF_NC
# LEAF_NODE_NO
# LEAF_NONSTC
# LEAF_NONSTN
# LEAF_NONSTP
# LEAF_P
# LEAF_PC
# LITRf_C
# LITRf_N_FLX
# LITRf_P_FLX
# MIN_LWP
# N2O_LITR
# N2O_vr
# N2_FIXN_FLX
# NBP
# NET_N_MIN
# NET_P_MIN
# NH3_LITR
# NH3_vr
# NH3can_FLX
# NH4_UPTK_FLX
# NO3_UPTK_FLX
# NODULE_C
# NODULE_N
# NODULE_P
# NPP
# O2_FLX
# O2_LITR
# O2_vr
# OMC_LITR
# OXY_STRESS
# PAR
# PETIOLE_C
# PLANT_BALANCE_C
# PLANT_BALANCE_N
# PLANT_BALANCE_P
# PLANT_C
# PLANT_N
# PLANT_P
# PO4_FIRE
# PO4_UPTK_FLX
# POPN
# PREC
# PSI_CAN
# PSI_RT_vr
# PSI_SURF
# PSI_vr
# Petiole_N
# Petiole_P
# Qinfl2soi_col
# RADN
# RESERVE_C
# RESERVE_N
# RESERVE_P
# ROOTST_C
# ROOTST_N
# ROOTST_P
# ROOT_C
# ROOT_N
# ROOT_NONSTC
# ROOT_NONSTN
# ROOT_NONSTP
# ROOT_P
# RUB_ACTVN
# RUNOFF_FLX
# RootH2OUptake_vr
# SEDIMENT_FLX
# SHOOTST_C
# SHOOTST_N
# SHOOTST_P
# SHOOT_C
# SHOOT_N
# SHOOT_P
# SNOWPACK
# SOIL_CO2_FLX
# SOIL_G
# SOIL_H
# SOIL_LE
# SOIL_RN
# SOL_RADN
# SSTORED_C
# SSTORED_N
# SSTORED_P
# STALK_C
# STALK_N
# STALK_P
# STANDING_DEAD_C
# STANDING_DEAD_N
# STANDING_DEAD_P
# STOML_RSC_CO2
# STOM_RSC
# SUB_DIC_FLX
# SUB_DIN_FLX
# SUB_DIP_FLX
# SUB_DOC_FLX
# SUB_DON_FLX
# SUB_DOP_FLX
# SURF_ELEV
# SURF_ICE
# SURF_LITRf_C_FLX
# SURF_LITRf_N_FLX
# SURF_LITRf_P_FLX
# SURF_WTR
# SURF_tLITR_C_FLX
# SURF_tLITR_N_FLX
# SURF_tLITR_P_FLX
# SUR_DIC_FLX
# SUR_DIN_FLX
# SUR_DIP_FLX
# SUR_DOC_FLX
# SUR_DON_FLX
# SUR_DOP_FLX
# TEMP_FN
# TEMP_LITR
# TEMP_SNOW
# TEMP_vr
# TL_N_FIXED_FLX
# TMAX_AIR
# TMAX_LITR
# TMAX_SOIL_vr
# TMIN_AIR
# TMIN_LITR
# TMIN_SOIL_vr
# TRANSPN
# TURG_CAN
# WIND
# WTR_STRESS
# WTR_TBL
# cEXCH_P_LITR
# cEXCH_P_vr
# cNH3_FLX
# cNH4_LITR
# cNH4t_vr
# cNO3_LITR
# cNO3t_vr
# cPO4_LITR
# cPO4_vr
# cTNC
# cTNN
# cTNP
# frcPARabs
# prtUP_NH4_vr
# prtUP_NO3_vr
# prtUP_PO4_vr
# sN2G_FLX
# sN2O_FLX
# sNH3_FLX
# tDIC
# tEXCH_PO4
# tFIRE_CH4
# tFIRE_CO2
# tLITRf_C
# tLITRf_N_FLX
# tLITRf_P
# tMICRO_C
# tMICRO_N
# tMICRO_P
# tNH4
# tNO3
# tPRECIP_P
# tPRECN
# tSOC_vr
# tSTANDING_DEAD_C
# tSTANDING_DEAD_N
# tSTANDING_DEAD_P
# tSWC
# tTRANSPN
# vICE_vr
# vWATER_vr

# %%
#get number of branches of the plants

numbranch_pft=nc_file.variables['BRANCH_NO'][:]
maxbrach_pft=np.max(numbranch_pft,axis=0)
numlivepft=np.sum(maxbrach_pft>0)
LAI=nc_file.variables['LAI_xstk'][:]
cGPP=nc_file.variables['ECO_GPP'][:]
eco_lai=nc_file.variables['ECO_LAI'][:]
rubactn=nc_file.variables['RUB_ACTVN'][:]
                          
tGPP=VSLib.cumts2ts(cGPP,year0)

CanGPP=nc_file.variables['CAN_GPP'][:]
print('#of live pft:')
print(numlivepft)
print('#of live branch: %d')                          
print(maxbrach_pft)                        
print(rubactn.shape)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [3], in <cell line: 6>()
#       4 maxbrach_pft=np.max(numbranch_pft,axis=0)
#       5 numlivepft=np.sum(maxbrach_pft>0)
# ----> 6 LAI=nc_file.variables['LAI'][:]
#       7 cGPP=nc_file.variables['ECO_GPP'][:]
#       8 eco_lai=nc_file.variables['ECO_LAI'][:]
#
# KeyError: 'LAI'

# %%
#show plant C allocation

morphunit=['leaf','petiole','stalk','reserve','husk','ear','grain']
        
parts_brch1 = nc_file.variables['C_PARTS_brch_01'][:]

parts_brch1_pft1=parts_brch1[:,:,0]
parts_brch1_pft2=parts_brch1[:,:,1]

fig, axs = plt.subplots(4, 1, figsize=(8, 6))

for nmp in range(len(morphunit)):
    axs[0].plot(np.sum(parts_brch1_pft1[:,0:nmp],axis=1),label=morphunit[nmp])
axs[0].set_xlabel('day')
axs[0].set_ylabel('Value')
axs[0].set_title('Line Plot of C allocation needle leave tree')
axs[0].legend(bbox_to_anchor=(1.05, 1), loc='upper left')    

axs[1].plot(LAI[:,0])
axs[1].set_xlabel('day')
axs[1].set_ylabel('Value')
axs[1].set_title('LAI needle leave tree')
cCanGPP=CanGPP[:,0].reshape(-1, 1)
tCanGPP=VSLib.cumts2ts(cCanGPP,year0)

axs[2].plot(tCanGPP)
axs[2].set_xlabel('day')
axs[2].set_ylabel('Value')
axs[2].set_title('GPP needle leave tree')

for nb in range(int(maxbrach_pft[0])):
    axs[3].plot(rubactn[:,nb,0],label=f'br {nb+1}')

axs[3].set_xlabel('day')
axs[3].set_ylabel('Value')
axs[3].set_title('Branch Rubisco activity')
axs[3].legend(bbox_to_anchor=(1.05, 1), loc='upper left')    

# Adjust layout
plt.tight_layout()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 19>()
#      16 axs[0].set_title('Line Plot of C allocation needle leave tree')
#      17 axs[0].legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# ---> 19 axs[1].plot(LAI[:,0])
#      20 axs[1].set_xlabel('day')
#      21 axs[1].set_ylabel('Value')
#
# NameError: name 'LAI' is not defined

# %%
fig, axs = plt.subplots(4, 1, figsize=(8, 6))

for nmp in range(len(morphunit)):
    axs[0].plot(np.sum(parts_brch1_pft2[:,0:nmp],axis=1),label=morphunit[nmp])
axs[0].set_xlabel('day')
axs[0].set_ylabel('Value')
axs[0].set_title('Line Plot of C allocation C3 grass')
axs[0].legend(bbox_to_anchor=(1.05, 1), loc='upper left')    


axs[1].plot(LAI[:,1])
axs[1].set_xlabel('day')
axs[1].set_ylabel('Value')
axs[1].set_title('LAI C3 grass')

cCanGPP=CanGPP[:,1].reshape(-1, 1)
tCanGPP=VSLib.cumts2ts(cCanGPP,year0)

axs[2].plot(tCanGPP)
axs[2].set_xlabel('day')
axs[2].set_ylabel('Value')
axs[2].set_title('GPP C3 grass')

for nb in range(int(maxbrach_pft[1])):
    axs[3].plot(rubactn[:,nb,1],label=f'br {nb+1}')

axs[3].set_xlabel('day')
axs[3].set_ylabel('Value')
axs[3].set_title('Branch Rubisco activity')
axs[3].legend(bbox_to_anchor=(1.05, 1), loc='upper left')    

# Adjust layout
plt.tight_layout()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 11>()
#       7 axs[0].set_title('Line Plot of C allocation C3 grass')
#       8 axs[0].legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# ---> 11 axs[1].plot(LAI[:,1])
#      12 axs[1].set_xlabel('day')
#      13 axs[1].set_ylabel('Value')
#
# NameError: name 'LAI' is not defined

# %%
fig, axs = plt.subplots(3, 1, figsize=(8, 6))
axs[0].plot(tGPP)
axs[0].set_title('GPP')
axs[1].plot(eco_lai)
axs[1].set_title('LAI')
plt.tight_layout()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 2>()
#       1 fig, axs = plt.subplots(3, 1, figsize=(8, 6))
# ----> 2 axs[0].plot(tGPP)
#       3 axs[0].set_title('GPP')
#       4 axs[1].plot(eco_lai)
#
# NameError: name 'tGPP' is not defined
