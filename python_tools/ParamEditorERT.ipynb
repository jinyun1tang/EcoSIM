# %%
#libraries
import numpy as np
from netCDF4 import Dataset
import subprocess
from pathlib import Path


from ParamEditor import ParEditor

#how to 
parfile='/Users/jinyuntang/work/github/EcoSIM/input_data/ecosim_pftpar_20240723.nc'
parEditor=ParEditor(pftparfile=parfile)
parEditor.reset(True)
#parfile='/Users/jinyuntang/work/github/ecosim_benchmark/smallset/Blodget'
pft='gr3s43'
pars={'PORT':0.35,'ETMX':500,'SLA1':1.e-2,'CHL':0.07}

parEditor.PlantParamModify(pft,pars,iscale=False,verbose=True)
#ParamModify(parfile,pft,parnm,0.8)
pft='ndlf43'
pars={'OSMO':-1.25,'PORT':5.e-03,'RSRR':500000,'RSRA':1000,'RTFQ':40}

parEditor.PlantParamModify(pft,pars,iscale=False,verbose=True)
# Out:
# Old jsonl files are removed.
# /Users/jinyuntang/work/github/EcoSIM/input_data/ecosim_pftpar_20240723.nc
# root porosity                                                                   : PORT for gr3s43 is 0.350000, and changed to 0.350000
# specific chlorophyll activity                                                   : ETMX for gr3s43 is 500.000000, and changed to 500.000000
# growth in leaf area vs mass                                                     : SLA1 for gr3s43 is 0.010000, and changed to 0.010000
# fraction of leaf protein in mesophyll(C3) chlorophyll                           : CHL for gr3s43 is 0.070000, and changed to 0.070000
# /Users/jinyuntang/work/github/EcoSIM/input_data/ecosim_pftpar_20240723.nc
# leaf osmotic potential at zero leaf water potential                             : OSMO for ndlf43 is -1.250000, and changed to -1.250000
# root porosity                                                                   : PORT for ndlf43 is 0.005000, and changed to 0.005000
# radial root resistivity                                                         : RSRR for ndlf43 is 500000.000000, and changed to 500000.000000
# axial root resistivity                                                          : RSRA for ndlf43 is 1000.000000, and changed to 1000.000000
# root branching frequency                                                        : RTFQ for ndlf43 is 40.000000, and changed to 40.000000

# %%
# Out:
# OSMO for ndlf43 is -1.250000, and changed to -1.250000
# PORT for ndlf43 is 0.002000, and changed to 0.002000
# RSRR for ndlf43 is 150000.000000, and changed to 500000.000000
# RSRA for ndlf43 is 1000.000000, and changed to 1000000.000000
# RTFQ for ndlf43 is 40.000000, and changed to 40.000000
# ETMX for gr3s43 is 500.000000, and changed to 500.000000
# GROUPX for gr3s43 is 8.000000, and changed to 8.000000
# SLA1 for gr3s43 is 0.010000, and changed to 0.010000
# CTC for gr3s43 is -10.000000, and changed to -10.000000
# RTFQ for gr3s43 is 300.000000, and changed to 300.000000
# PORT for gr3s43 is 0.340000, and changed to 0.340000
# RSRR for gr3s43 is 100000.000000, and changed to 500000.000000
# RSRA for gr3s43 is 800.000000, and changed to 1000000.000000
# OSMO for gr3s43 is -1.250000, and changed to -1.250000
