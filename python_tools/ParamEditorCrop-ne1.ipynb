# %%
#libraries
import numpy as np
from netCDF4 import Dataset
import subprocess
from pathlib import Path


from ParamEditor import ParEditor

#how to 
parfile='/Users/jinyuntang/work/github/EcoSIM/input_data/ecosim_pftpar_20260225.nc'
micparfile='/Users/jinyuntang/work/github/EcoSIM/input_data/MicrobePars.20260211.nc'
parEditor=ParEditor(pftparfile=parfile,micparfile=micparfile)
#parEditor.CopyPlantPft('maiz31','maiz41')
#compare two pfts

# %%
#how to 
parEditor=ParEditor(pftparfile=parfile)

pft='maiz41' #based on ponderosa pine
pars={'VCMX4':1000,'UPKMZH':5,'UPKMZO':10,'XRNI':0.025,'XRLA':0.015,'ETMX':1000,'SLA1':0.015,'GROUPX':13,
      'GRDM':0.15,'UPMXZO':5.e-2,'UPMXZH':2.5e-2,'RUBP':0.10,'PEPC':0.05,'CHL':0.35,'fCHLMESO':0.6,
      'RRAD1M':0.5e-3,'RRAD2M':0.1e-3,'RTFQ':3600,'PR':0.1,'PORT':0.15,'RRAD1M':0.5e-3,'RRAD2M':0.05e-3,
      'PTSHT':0.05,'RSRR':5.e7/3600,'RSRA':5.e11/3600,'FCO2':0.4,'CNWL':2.7,'CPWL':35,'CNWR':2.2,'CPWR':20,
      'ANGBR':90,'ANGSH':60,'WDLF':10,'PhiMEAN':0.10,'GRW2L':0.66}
parEditor.PlantParamModify(pft,pars,iscale=False,verbose=True)
# Out:
# /Users/jinyuntang/work/github/EcoSIM/input_data/ecosim_pftpar_20260225.nc
# specific PEP carboxylase activity                                                                   : VCMX4 for maiz41 is 1000.0, and changed to 1000
# NH4 uptake Km                                                                                       : UPKMZH for maiz41 is 5.0, and changed to 5
# NO3 uptake Km                                                                                       : UPKMZO for maiz41 is 10.0, and changed to 10
# rate of node initiation at 25oC                                                                     : XRNI for maiz41 is 0.02500000037252903, and changed to 0.025
# rate of leaf appearance at 25oC                                                                     : XRLA for maiz41 is 0.014999999664723873, and changed to 0.015
# ...

# %%
print(0.4166666667*24)
# Out:
# 10.0000000008

# %%
print(0.8*3.3)
# Out:
# 2.64
