# %%
#libraries
import numpy as np
from netCDF4 import Dataset
import subprocess
from pathlib import Path


from ParamEditor import ParEditor

#how to 
parfile='/Users/jinyuntang/work/github/EcoSIM/input_data/ecosim_pftpar_20251018.nc'
micparfile='/Users/jinyuntang/work/github/EcoSIM/input_data/MicrobePars.20251015.nc'
parEditor=ParEditor(pftparfile=parfile,micparfile=micparfile)

# %%
#how to 

pft='rice34'
pftvars={'ETMX':600,'SLA1':0.01,'PORT':0.4,'VCMX':60,'RTFQ':600,'CHL':0.03,'RUBP':0.3,'GROUPX':10,'TAUR':0.1,'FCO2':0.7,'UPMXZH':0.5,
         'ZTYPI':2.5,'UPMXZO':0.5,'RCS':0.125}
parEditor.PlantParamModify(pft,pftvars,iscale=False,verbose=True)
#micpars={'VMXCH4gH2':0.8,'VMXCH4gAcet':0.8,'VMXF':0.9};
#parEditor.MicrobeParamModify(micpars,iscale=True)
# Out:
# /Users/jinyuntang/work/github/EcoSIM/input_data/ecosim_pftpar_20251018.nc
# specific chlorophyll activity                                                                       : ETMX for rice34 is 600.000000, and changed to 600.000000
# growth in leaf area vs mass                                                                         : SLA1 for rice34 is 0.010000, and changed to 0.010000
# root porosity                                                                                       : PORT for rice34 is 0.400000, and changed to 0.400000
# specific C3 rubisco carboxylase                                                                     : VCMX for rice34 is 60.000000, and changed to 60.000000
# root branching frequency                                                                            : RTFQ for rice34 is 600.000000, and changed to 600.000000
# fraction of leaf protein in mesophyll(C3) chlorophyll                                               : CHL for rice34 is 0.030000, and changed to 0.030000
# fraction of leaf protein in rubisco                                                                 : RUBP for rice34 is 0.300000, and changed to 0.300000
# initial plant maturity group, aka minimum number of vegetative nodes initiated before floral        : GROUPX for rice34 is 10.000000, and changed to 10.000000
# leaf SW transmission                                                                                : TAUR for rice34 is 0.100000, and changed to 0.100000
# intercellular                                                                                       : FCO2 for rice34 is 0.700000, and changed to 0.700000
# NH4 max uptake                                                                                      : UPMXZH for rice34 is 0.250000, and changed to 0.500000
# thermal adaptation zone                                                                             : ZTYPI for rice34 is 2.500000, and changed to 2.500000
# NO3 max uptake                                                                                      : UPMXZO for rice34 is 0.250000, and changed to 0.500000
# e-folding turgor pressure for stomatal resistance                                                   : RCS for rice34 is -8.000000, and changed to 0.125000
