# %%
#libraries
import numpy as np
from netCDF4 import Dataset
import subprocess
from pathlib import Path


from ParamEditor import ParEditor

#how to 
parfile='/Users/jinyuntang/work/github/EcoSIM/input_data/ecosim_pftpar_20251224.nc'
micparfile='/Users/jinyuntang/work/github/EcoSIM/input_data/MicrobePars.20251015.nc'
parEditor=ParEditor(pftparfile=parfile,micparfile=micparfile)

# %%
#how to 

pft='rice34'
pftvars={'ETMX':600,'SLA1':0.006,'PORT':0.45,'VCMX':60,'RTFQ':600,'CHL':0.17,'RUBP':0.3,'GROUPX':9,'TAUR':0.1,'FCO2':0.7,'UPMXZH':0.5,
         'ZTYPI':2.5,'UPMXZO':0.5,'RCS':0.125}
parEditor.PlantParamModify(pft,pftvars,iscale=False,verbose=True)
#micpars={'VMXCH4gH2':0.8,'VMXCH4gAcet':0.8,'VMXF':0.9};
#parEditor.MicrobeParamModify(micpars,iscale=True)
# Out:
# /Users/jinyuntang/work/github/EcoSIM/input_data/ecosim_pftpar_20251224.nc
# specific chlorophyll activity                                                                       : ETMX for rice34 is 600.0, and changed to 600
# growth in leaf area vs mass                                                                         : SLA1 for rice34 is 0.006000000052154064, and changed to 0.006
# root porosity                                                                                       : PORT for rice34 is 0.44999998807907104, and changed to 0.45
# specific C3 rubisco carboxylase                                                                     : VCMX for rice34 is 60.0, and changed to 60
# root branching frequency                                                                            : RTFQ for rice34 is 600.0, and changed to 600
# ...
