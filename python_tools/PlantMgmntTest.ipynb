# %%
#code to write plant managment information
import numpy as np
from datetime import datetime

# %%
plantHrvst={'iHarvstType':0,'jHarvstType':0,'CanopyHeightCut':0,'THIN':0','frac_leaf_hvsted':0,'frac_fine_nonleaf_hvsted':0,
            'frac_wood_hvsted':0,'frac_stand_dead_hvsted':0,}
