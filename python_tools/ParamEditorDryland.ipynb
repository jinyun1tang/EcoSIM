# %%
#libraries
import numpy as np
from netCDF4 import Dataset
import subprocess
from pathlib import Path

# %%
def ParamModify(parfile,pft,parnms,parvals,iscale=False):
    """
    modify parameter parnm of pft on file parfile
    """
    
    with Dataset(parfile, 'r+') as nc_file:
        variable = nc_file.variables['pfts']
        pft_loc=0
        for var in variable:
            result_string=''
            for byte in var:
                if byte:
                    result_string=''.join([result_string,byte.decode('utf-8')])
            #locate the pft       
            if result_string.strip()==pft:
                #locate the variable
                for parnm,parval in zip(parnms,parvals):
                    variable1=nc_file.variables[parnm]
                    if iscale:
                        print("%s for %s is %f, and changed to %f"%(parnm,pft,variable1[pft_loc],parval*variable1[pft_loc]))
                        variable1[pft_loc]=parval*variable1[pft_loc]
                    else:
                        print("%s for %s is %f, and changed to %f"%(parnm,pft,variable1[pft_loc],parval))
                        variable1[pft_loc]=parval
                break
            pft_loc=pft_loc+1

# %%
#how to 
parfile='../input_data/dryland_pft_20230509.nc'
pft='maiz31'
parnms=['ETMX','SLA1','PORT','VCMX','RSRR','RSRA']
parvals=[400,0.002,0.2,50,50000000,10000]
ParamModify(parfile,pft,parnms,parvals,iscale=False)

#ParamModify(parfile,pft,parnm,0.8)
#parnm='RSRR'
#parnm='RSRA'
pft='soyb31'
parnms=['RSRR','RSRA']
parvals=[40000000,40000]

ParamModify(parfile,pft,parnms,parvals,iscale=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 6
#       4 parnms=['ETMX','SLA1','PORT','VCMX','RSRR','RSRA']
#       5 parvals=[400,0.002,0.2,50,50000000,10000]
# ----> 6 ParamModify(parfile,pft,parnms,parvals,iscale=False)
#       8 #ParamModify(parfile,pft,parnm,0.8)
#       9 #parnm='RSRR'
#      10 #parnm='RSRA'
#      11 pft='soyb31'
#
# Cell In[7], line 7, in ParamModify(parfile, pft, parnms, parvals, iscale)
#       2 """
#       3 modify parameter parnm of pft on file parfile
#       4 """
#       6 with Dataset(parfile, 'r+') as nc_file:
# ----> 7     variable = nc_file.variables['pfts']
#       8     pft_loc=0
#       9     for var in variable:
#
# KeyError: 'pfts'
