# %%
from RunModel import RunModel


# The directory where the executable is located
model_cfg={'target_directory':'/Users/jinyuntang/work/github/EcoSIM/examples/run_dir/blodgett/',
    'executable_name':'../../../local/bin/ecosim.f90.x', # Use './' for executables in that directory
    'namelist_file':'./Blodget.ctrl.namelist'}

runmodel=RunModel(model_cfg)

runmodel.run()
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
