# %% [markdown]
# # The following script will change ECOSYS input files into EcoSIM input files

# %%
config_plm_dict={
'case':'PLM',
'mdir':'/Users/jinyuntang/work/github/ecosys_benchmark/plmrEcosys/',
'outdir':'/Users/jinyuntang/work/github/ecosim_benchmark/smallset/PLM/',    
'pftf':'nlegp1:nlegg1',  
'sitef':'st074773',
'topf':'tp074773',        
'ntopu':'7',  #number of grids
'ncol':'7',
'nrow':'1',
'NHW':'1',
'NVN':'1',
'NHE':'7',
'NVS':'1'    
}    

config_fen_dict={
'case':'FenStordIsland',
'mdir':'/Users/jinyuntang/work/github/ecosys_benchmark/fen_sy/',
'outdir':'/Users/jinyuntang/work/github/ecosim_benchmark/smallset/FenStordIsland/',    
'pft_path':'/Users/jinyuntang/work/github/ecosys_benchmark/fen_sy/pfts/',       
'pftf':'sdlxxp2:sdlxxp_no',  
'sitef':'sdlsite',
'topf':'sdltopo', 
'gfname':'FenStordIsland',            
'ntopu':'1',  #number of grids
'ncol':'1',
'nrow':'1',
'NHW':'1',
'NVN':'1',
'NHE':'1',
'NVS':'1'    
}    


config_sorghum_dict={
'case':'Sorghum',
'mdir':'/Users/jinyuntang/work/github/ecosys_benchmark/sorghum/plt_sorg-2/',
'sitef':'mesite',
'topf':'metopo',    
'pftf':'mexxxxp',
'mefile':'mexxxxm',
'years':'2001-2003',    
'year':'2001-2003',        
'outdir':'/Users/jinyuntang/work/github/ecosim_benchmark/smallset/Sorghum/',    
'pft_path':'/Users/jinyuntang/work/github/ecosys_benchmark/sorghum/plt_sorg-2/pfts/',   
'gfname':'sorghum',    
'NH1':[1],
'NV1':[1],
'NH2':[1],
'NV2':[1],
'ntopu':'1',
'ncol':'1',
'nrow':'1',
'NHW':'1',
'NVN':'1',
'NHE':'1',
'NVS':'1'    
}


config_crop_ro1_dict={
'case':'crop-ro1',
'mdir':'/Users/jinyuntang/work/github/ecosim_benchmark/midwest_crops/ro1/',
'sitef':'mesite',
'topf':'metopo',    
'pftf':'mexxxxp',
'mefile':'mexxxxm',
'years':'2004-2012',    
'year':'2004-2012',        
'outdir':'/Users/jinyuntang/work/github/ecosim_benchmark/Crop/ro1/',    
'pft_path':'/Users/jinyuntang/work/github/ecosim_benchmark/midwest_crops/ro1/pfts/',   
'gfname':'crop',    
'NH1':[1],
'NV1':[1],
'NH2':[1],
'NV2':[1],
'ntopu':'1',
'ncol':'1',
'nrow':'1',
'NHW':'1',
'NVN':'1',
'NHE':'1',
'NVS':'1'    
}

config_crop_bo1_dict={
'case':'crop-bo1',
'mdir':'/Users/jinyuntang/work/github/ecosim_benchmark/midwest_crops/bo1/',
'sitef':'mesite',
'topf':'metopo',    
'pftf':'mexxxxp',
'mefile':'mexxxxm',
'years':'2001-2008',    
'year':'2001-2008',        
'outdir':'/Users/jinyuntang/work/github/ecosim_benchmark/Crop/bo1/',    
'pft_path':'/Users/jinyuntang/work/github/ecosim_benchmark/midwest_crops/bo1/pfts/',   
'gfname':'crop',    
'NH1':[1],
'NV1':[1],
'NH2':[1],
'NV2':[1],
'ntopu':'1',
'ncol':'1',
'nrow':'1',
'NHW':'1',
'NVN':'1',
'NHE':'1',
'NVS':'1'    
}

config_crop_br1_dict={
'case':'crop-br1',
'mdir':'/Users/jinyuntang/work/github/ecosim_benchmark/midwest_crops/br1/',
'sitef':'mesite',
'topf':'metopo',    
'pftf':'mexxxxp',
'mefile':'mexxxxm',
'years':'2005-2011',    
'year':'2005-2011',        
'outdir':'/Users/jinyuntang/work/github/ecosim_benchmark/Crop/br1/',    
'pft_path':'/Users/jinyuntang/work/github/ecosim_benchmark/midwest_crops/br1/pfts/',   
'gfname':'crop',    
'NH1':[1],
'NV1':[1],
'NH2':[1],
'NV2':[1],
'ntopu':'1',
'ncol':'1',
'nrow':'1',
'NHW':'1',
'NVN':'1',
'NHE':'1',
'NVS':'1'    
}

config_crop_ib1_dict={
'case':'crop-ib1',
'mdir':'/Users/jinyuntang/work/github/ecosim_benchmark/midwest_crops/ib1/',
'sitef':'mesite',
'topf':'metopo',    
'pftf':'mexxxxp',
'mefile':'mexxxxm',
'years':'2005-2011',    
'year':'2005-2011',        
'outdir':'/Users/jinyuntang/work/github/ecosim_benchmark/Crop/ib1/',    
'pft_path':'/Users/jinyuntang/work/github/ecosim_benchmark/midwest_crops/ib1/pfts/',   
'gfname':'crop',    
'NH1':[1],
'NV1':[1],
'NH2':[1],
'NV2':[1],
'ntopu':'1',
'ncol':'1',
'nrow':'1',
'NHW':'1',
'NVN':'1',
'NHE':'1',
'NVS':'1'    
}

config_crop_ne1_dict={
'case':'crop-ne1',
'mdir':'/Users/jinyuntang/work/github/ecosim_benchmark/midwest_crops/ne1/',
'sitef':'mesite',
'topf':'metopo',    
'pftf':'mexxxxp',
'mefile':'mexxxxm',
'years':'2001-2012',    
'year':'2001-2012',        
'outdir':'/Users/jinyuntang/work/github/ecosim_benchmark/Crop/ne1/',    
'pft_path':'/Users/jinyuntang/work/github/ecosim_benchmark/midwest_crops/ne1/pfts/',   
'gfname':'crop',    
'NH1':[1],
'NV1':[1],
'NH2':[1],
'NV2':[1],
'ntopu':'1',
'ncol':'1',
'nrow':'1',
'NHW':'1',
'NVN':'1',
'NHE':'1',
'NVS':'1'    
}

config_crop_ne2_dict={
'case':'crop-ne2',
'mdir':'/Users/jinyuntang/work/github/ecosim_benchmark/midwest_crops/ne2/',
'sitef':'mesite',
'topf':'metopo',    
'pftf':'mexxxxp',
'mefile':'mexxxxm',
'years':'2001-2012',    
'year':'2001-2012',        
'outdir':'/Users/jinyuntang/work/github/ecosim_benchmark/Crop/ne2/',    
'pft_path':'/Users/jinyuntang/work/github/ecosim_benchmark/midwest_crops/ne2/pfts/',   
'gfname':'crop',    
'NH1':[1],
'NV1':[1],
'NH2':[1],
'NV2':[1],
'ntopu':'1',
'ncol':'1',
'nrow':'1',
'NHW':'1',
'NVN':'1',
'NHE':'1',
'NVS':'1'    
}

config_crop_ne3_dict={
'case':'crop-ne3',
'mdir':'/Users/jinyuntang/work/github/ecosim_benchmark/midwest_crops/ne3/',
'sitef':'mesite',
'topf':'metopo',    
'pftf':'mexxxxp',
'mefile':'mexxxxm',
'years':'2001-2012',    
'year':'2001-2012',        
'outdir':'/Users/jinyuntang/work/github/ecosim_benchmark/Crop/ne3/',    
'pft_path':'/Users/jinyuntang/work/github/ecosim_benchmark/midwest_crops/ne3/pfts/',   
'gfname':'crop',    
'NH1':[1],
'NV1':[1],
'NH2':[1],
'NV2':[1],
'ntopu':'1',
'ncol':'1',
'nrow':'1',
'NHW':'1',
'NVN':'1',
'NHE':'1',
'NVS':'1'    
}

config_fire_dict={
'case':'FireCA',
'mdir':'/Users/jinyuntang/work/github/ecosys_benchmark/Fire_run/',
'sitef':'st059384',
'topf':'tp059384',    
'firef':'b_smf',    
'pftf':'pft35_p:pft35_g',  
'outdir':'/Users/jinyuntang/work/github/ecosim_benchmark/smallset/FireCA/',    
'pft_path':'/Users/jinyuntang/work/github/ecosys_benchmark/Fire_run/pfts/',   
'gfname':'FireCA',        
'NH1':[1],
'NV1':[1],
'NH2':[1],
'NV2':[1],
'ntopu':'1',
'ncol':'1',
'nrow':'1',
'NHW':'1',
'NVN':'1',
'NHE':'1',
'NVS':'1'    
}

config_ert_dict={
'case':'ERT',
'mdir':'/Users/jinyuntang/work/github/ecosys_benchmark/smallset/ERT_run/',
'outdir':'/Users/jinyuntang/work/github/ecosim_benchmark/smallset/ERT/',    
'pft_path':'/Users/jinyuntang/work/github/ecosys_benchmark/smallset/ERT_run/pft_path/',       
'pftf':'pft_ert_p:pft_ert_g',  
'sitef':'st074773_e',
'topf':'tp074773_e_test',       
'gfname':'ERT',            
'ntopu':'6',  #number of grids
'ncol':'6',
'nrow':'1',
'NHW':'1',
'NVN':'1',
'NHE':'6',
'NVS':'1'    
}    


config_dl_dict={
'case':'DaLake',
'mdir':'/Users/jinyuntang/work/github/ecosys_benchmark/dl_from_robert/',
'outdir':'/Users/jinyuntang/work/github/ecosim_benchmark/smallset/DaLake/',    
'pft_path':'/Users/jinyuntang/work/github/ecosys_benchmark/dl_from_robert/pft/',       
'pftf':'dlmt00p:dlmtxxp',  
'sitef':'dlmts',
'topf':'dlmtto',
'soil_mgmt':'',
'gfname':'DaLake',            
'ntopu':'6',  #number of grids
'ncol':'1',
'nrow':'6',
'NH1':[1,1],
'NV1':[1,1],
'NH2':[1,5],
'NV2':[4,6],    
'NHW':'1',
'NVN':'1',
'NHE':'1',
'NVS':'6'    
}    

config_ricetwt_dict={
'case':'RiceUSTWT',
'mdir':'//Users/jinyuntang/work/github/ecosim_benchmark/Rice_US-Twt/ecosysrun/',
'sitef':'mesite',
'topf':'metopo',    
'pftf':'mexxxxp',
'mefile':'mexxxxm',
'years':'2008-2016',    
'year':'2008-2016',        
'soil_mgmt':'',    
'outdir':'/Users/jinyuntang/work/github/ecosim_benchmark/RiceUSTWT/',    
'pft_path':'/Users/jinyuntang/work/github/ecosim_benchmark/Rice_US-Twt/ecosysrun/pfts/',   
'gfname':'Rice',    
'NH1':[1],
'NV1':[1],
'NH2':[1],
'NV2':[1],
'ntopu':'1',
'ncol':'1',
'nrow':'1',
'NHW':'1',
'NVN':'1',
'NHE':'1',
'NVS':'1'    
}

config_dict=config_ricetwt_dict

from SiteTopoWriter import write_site_topo_data

#write site and topographic file
write_site_topo_data(config_dict)

#write soil management file
from soilManagementWriter import write_soil_mgmt

if config_dict['mefile']:
    write_soil_mgmt(config_dict)

#write pft managment file
from pftMgmtWriter import write_pft_mgmt

write_pft_mgmt(config_dict)

from PlantTraitWriter import write_plant_traits
write_plant_traits(config_dict['pft_path'],config_dict['gfname'],config_dict['outdir'])
# Out:
# generate grid data for RiceUSTWT
# outputdir=/Users/jinyuntang/work/github/ecosim_benchmark/RiceUSTWT/
# check file /Users/jinyuntang/work/github/ecosim_benchmark/RiceUSTWT/RiceUSTWT_grid_20251017.nc
# NH1=1,NH2=1,NV1=1,NV2=1
# generate soil managment data for RiceUSTWT
# check file /Users/jinyuntang/work/github/ecosim_benchmark/RiceUSTWT/RiceUSTWT_soilmgmt_20251017.nc
# read file //Users/jinyuntang/work/github/ecosim_benchmark/Rice_US-Twt/ecosysrun/me2008m
# ['me2008t', 'me2008f', 'NO']
# read file //Users/jinyuntang/work/github/ecosim_benchmark/Rice_US-Twt/ecosysrun/me2009m
# ['me2009t', 'me2009f', 'NO']
# read file //Users/jinyuntang/work/github/ecosim_benchmark/Rice_US-Twt/ecosysrun/me2010m
# ['me2010t', 'me2010f', 'NO']
# read file //Users/jinyuntang/work/github/ecosim_benchmark/Rice_US-Twt/ecosysrun/me2011m
# ['me2011t', 'me2011f', 'NO']
# read file //Users/jinyuntang/work/github/ecosim_benchmark/Rice_US-Twt/ecosysrun/me2012m
# ['me2012t', 'me2012f', 'NO']
# ...

# %%
a=[3,[4,5],4]
print(a[1])
# Out:
# [4, 5]

# %%
s='/Users/jinyuntang/work/github/EcoSIM/input_data/ecosim_pftpar_20240723.nc'
parts=s.split('/')
print(parts[-1])
parts1=parts[-1].split('.')
print(parts1[0])
# Out:
# ecosim_pftpar_20240723.nc
# ecosim_pftpar_20240723

# %%
pars={'PORT':0.35,'ETMX':500,'SLA1':1.e-2,'CHL':0.07}
print(len(pars))
# Out:
# 4
