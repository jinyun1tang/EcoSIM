# %%
#libraries
import numpy as np
from netCDF4 import Dataset
import subprocess
from pathlib import Path


from ParamEditor import ParEditor

#how to 
#parfile='/Users/jinyuntang/work/github/ecosim_tests_by_others/new-data/input-nc-files/pft-lusignan.nc'
#parfile='/Users/jinyuntang/work/github/EcoSIM/input_data/ecosim_pftpar_20251224.nc'
parfile='/Users/jinyuntang/work/ibi/grass_clova_pftpar.nc'
parEditor=ParEditor(pftparfile=parfile)
#parEditor.CopyPlantPft("clvs35",'clvs32')
# Out:
# /Users/jinyuntang/work/ibi/grass_clova_pftpar.nc
# Parameters for clvs35 not found

# %%
pft='gr3s32'

print(pft)
pars={'CHL':0.25,'RUBP':0.30,'ETMX':500,'SLA1':0.005,'UPMXZO':0.005,'UPMXZH':0.006,'UPKMZH':10,'UPKMZO':25,'VCMX':80,'CFI':0.9,
      'RSRA':200000000,'RSRR':10000,'RTFQ':600,'PTSHT':3.e-3,'RCS':0.2,'IGTYP':1,'CNWL':2.8,'CPWL':42.,'CNWR':2.3,'CPWR':28.0,
     'FCO2':0.7,'RRAD2M':0.1e-3,'RRAD1M':0.3e-3,'GRMX':3.e-4,'PORT':0.1,'WDLF':5,'ANGSH':75,'ZTYPI':2.,'CTC':-5,'PhiMEAN':0.05}
parEditor.PlantParamModify(pft,pars,iscale=False,verbose=True)
# Out:
# gr3s32
# /Users/jinyuntang/work/ibi/grass_clova_pftpar.nc
# Fraction of leaf protein binded with chlorophyll                                                    : CHL for gr3s32 is 0.02500000037252903, and changed to 0.25
# fraction of leaf protein in rubisco                                                                 : RUBP for gr3s32 is 0.125, and changed to 0.3
# specific chlorophyll activity                                                                       : ETMX for gr3s32 is 405.0, and changed to 500
# growth in leaf area vs mass                                                                         : SLA1 for gr3s32 is 0.003329999977722764, and changed to 0.005
# NO3 max uptake                                                                                      : UPMXZO for gr3s32 is 0.004999999888241291, and changed to 0.005
# NH4 max uptake                                                                                      : UPMXZH for gr3s32 is 0.004999999888241291, and changed to 0.006
# NH4 uptake Km                                                                                       : UPKMZH for gr3s32 is 0.4000000059604645, and changed to 10
# NO3 uptake Km                                                                                       : UPKMZO for gr3s32 is 0.3499999940395355, and changed to 25
# specific C3 rubisco carboxylase                                                                     : VCMX for gr3s32 is 45.0, and changed to 80
# initial clumping factor                                                                             : CFI for gr3s32 is 0.8999999761581421, and changed to 0.9
# axial root resistivity                                                                              : RSRA for gr3s32 is 4000000000.0, and changed to 200000000
# radial root resistivity                                                                             : RSRR for gr3s32 is 10000.0, and changed to 10000
# root branching frequency                                                                            : RTFQ for gr3s32 is 250.0, and changed to 600
# rate constant for equilibrating shoot-root nonstructural C concentration                            : PTSHT for gr3s32 is 0.05000000074505806, and changed to 0.003
# e-folding turgor pressure for stomatal resistance                                                   : RCS for gr3s32 is 0.20000000298023224, and changed to 0.2
# root profile                                                                                        : IGTYP for gr3s32 is 1, and changed to 1
# Protein C to leaf N ratio in plant leaves                                                           : CNWL for gr3s32 is 2.5999999046325684, and changed to 2.8
# Protein C to leaf P ratio in plant leaves                                                           : CPWL for gr3s32 is 28.399999618530273, and changed to 42.0
# Protein C to root N ratio in plant roots                                                            : CNWR for gr3s32 is 2.1500000953674316, and changed to 2.3
# Protein C to root P ratio in plant roots                                                            : CPWR for gr3s32 is 40.0, and changed to 28.0
# intercellular                                                                                       : FCO2 for gr3s32 is 0.699999988079071, and changed to 0.7
# radius of secondary roots                                                                           : RRAD2M for gr3s32 is 9.999999747378752e-05, and changed to 0.0001
# radius of primary root tips                                                                         : RRAD1M for gr3s32 is 9.999999747378752e-05, and changed to 0.0003
# maximum seed size per seed                                                                          : GRMX for gr3s32 is 0.004999999888241291, and changed to 0.0003
# root porosity                                                                                       : PORT for gr3s32 is 0.05000000074505806, and changed to 0.1
# leaf length vs width ratio                                                                          : WDLF for gr3s32 is 5.0, and changed to 5
# petiole angle from horizontal                                                                       : ANGSH for gr3s32 is 90.0, and changed to 75
# thermal adaptation zone                                                                             : ZTYPI for gr3s32 is 1.0, and changed to 2.0
# chilling temperature for CO2 fixation, seed loss                                                    : CTC for gr3s32 is -10.0, and changed to -5
# the mean fraction found in the root as lumen for non-tree roots                                     : PhiMEAN for gr3s32 is 0.019999999552965164, and changed to 0.05
