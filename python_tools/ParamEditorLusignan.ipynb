# %%
#libraries
import numpy as np
from netCDF4 import Dataset
import subprocess
from pathlib import Path


from ParamEditor import ParEditor

#how to 
parfile='/Users/jinyuntang/work/github/ecosim_tests_by_others/new-data/input-nc-files/pft-lusignan.nc'
parEditor=ParEditor(pftparfile=parfile)

# %%
pft='gr3s32'

print(pft)
pars={'CHL':0.1,'ETMX':500,'SLA1':0.01,'UPMXZO':0.5,'UPMXZH':0.8,'RUBP':0.32,'VCMX':60,'RRAD2M':1.e-5,'CFI':0.9,
      'RSRA':50000000,'RSRR':10000,'RTFQ':1500,'PTSHT':5.e-3,'RCS':0.2,'IGTYP':1}
parEditor.PlantParamModify(pft,pars,iscale=False,verbose=True)
# Out:
# gr3s32
# /Users/jinyuntang/work/github/ecosim_tests_by_others/new-data/input-nc-files/pft-lusignan.nc
# fraction of leaf protein in mesophyll(C3) chlorophyll                                               : CHL for gr3s32 is 0.100000, and changed to 0.100000
# specific chlorophyll activity                                                                       : ETMX for gr3s32 is 500.000000, and changed to 500.000000
# growth in leaf area vs mass                                                                         : SLA1 for gr3s32 is 0.040000, and changed to 0.010000
# NO3 max uptake                                                                                      : UPMXZO for gr3s32 is 0.500000, and changed to 0.500000
# NH4 max uptake                                                                                      : UPMXZH for gr3s32 is 0.800000, and changed to 0.800000
# fraction of leaf protein in rubisco                                                                 : RUBP for gr3s32 is 0.320000, and changed to 0.320000
# specific C3 rubisco carboxylase                                                                     : VCMX for gr3s32 is 60.000000, and changed to 60.000000
# radius of secondary roots                                                                           : RRAD2M for gr3s32 is 0.000010, and changed to 0.000010
# initial clumping factor                                                                             : CFI for gr3s32 is 0.900000, and changed to 0.900000
# axial root resistivity                                                                              : RSRA for gr3s32 is 50000000.000000, and changed to 50000000.000000
# radial root resistivity                                                                             : RSRR for gr3s32 is 10000.000000, and changed to 10000.000000
# root branching frequency                                                                            : RTFQ for gr3s32 is 1500.000000, and changed to 1500.000000
# rate constant for equilibrating shoot-root nonstructural C concentration                            : PTSHT for gr3s32 is 0.005000, and changed to 0.005000
# shape parameter for stomatal resistance vs leaf turgor potential                                    : RCS for gr3s32 is 0.200000, and changed to 0.200000
# root profile                                                                                        : IGTYP for gr3s32 is 1.000000, and changed to 1.000000
